# %%
from keras.layers import LSTM

model3 = Sequential()
model3.add(LSTM(128, input_shape=(300, 1)))
model3.add(Dense(64, activation='relu'))
model3.add(Dropout(0.20))
model3.add(Dense(5))

early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=4, verbose=1)
model3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))

binary_lstm_history = model3.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val), callbacks=[early_stop, lr_scheduler])
